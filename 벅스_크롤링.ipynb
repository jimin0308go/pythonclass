# %% [markdown]
# <a href="https://colab.research.google.com/github/jimin0308go/pythonclass/blob/main/%EB%B2%85%EC%8A%A4_%ED%81%AC%EB%A1%A4%EB%A7%81.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#벅스 크롤링

# %%
from selenium import webdriver
from bs4 import Beautifulsoup    #인터넷으로 가져온 데이터 청소

# %%
pip install selenium #selenium 설치
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 6.3 MB 14.8 MB/s
# ...
#      |████████████████████████████████| 384 kB 36.9 MB/s
# ...
#      |████████████████████████████████| 140 kB 54.1 MB/s
# ...
#      |████████████████████████████████| 58 kB 4.1 MB/s
# ...
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 1.24.3
#     Uninstalling urllib3-1.24.3:
#       Successfully uninstalled urllib3-1.24.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# requests 2.23.0 requires urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1, but you have urllib3 1.26.13 which is incompatible.
# ...

# %%
from selenium import webdriver    # 인터넷으로 사이트 연결
from bs4 import BeautifulSoup      # 인터넷으로 긁어온 데이터 정제

# %%
import requests #파이썬으로 인터넷 사이트 연결
from bs4 import BeautifulSoup  as bs

# %%
url = "https://music.bugs.co.kr/chart"
html = requests.get(url)

print(html)

print(html)
# Out:
# <Response [200]>
# <Response [200]>

# %%
print(html.text)
# Out:
# <!DOCTYPE html>
# <html lang="ko">
# <head>
# 	<!-- bgsweb-www909 -->
# 	<meta charset="utf-8">
# 	<meta http-equiv="X-UA-Compatible" content="IE=edge">
# 	<meta name="keywords" content="음악,음악 스트리밍,최신음악,인기가요,뮤직비디오,앨범,플레이어,mp3 다운로드,놀면뭐하니,유플래쉬,유플래시" />
# 	<meta name="viewport" content="width=device-width, initial-scale=1" />
#
# <script type="text/javascript">
# 	if(!(location.href.indexOf("music.bugs.co.kr/newPlayer") >= 0 || location.href.indexOf("music.bugs.co.kr/newRadio") >= 0 || location.href.indexOf("localhost") >= 0))
# 		document.domain = 'bugs.co.kr';
#
# 	var g_urlBase = "https://www.bugs.co.kr";
# 	var g_urlWww = "https://www.bugs.co.kr";
# 	var g_urlSecure = "https://secure.bugs.co.kr";
# 	var g_urlMusic = "https://music.bugs.co.kr";
# 	var g_urlMusicSecure = "https://music.bugs.co.kr";
# 	var g_urlMember = "https://secure.bugs.co.kr/member";
# 	var g_urlFile = "https://file.bugsm.co.kr/wbugs";
# 	var g_urlFile_n ="https://file.bugsm.co.kr/nbugs";
# ...

# %%
soup = bs(html.text) #가져온 데이터는 텍스트 이기 때문에 분석하기 가 힘들다 따라서 
  # 분석하기 쉽게 bs BeautiSoup 을 통해 정제 한다. 
  # 위와 차이는 없어 보이지만 내부적 차이가 존재함.

# %%
len(soup.select('tr'))
# Out:
# 104

# %%
len(soup.select('tbody > tr'))
# Out:
# 103

# %%
len(soup.select('table.byChart > tbody > tr'))
# Out:
# 100

# %%
songs = soup.select('table.byChart > tbody > tr')
song = songs[0]
print(song)
# Out:
# <tr albumid="4073469" artistid="80010025" multiartist="N" mvid="607295" rowtype="track" trackid="6155092">
# <input name="_isStream" type="hidden" value="6155092"/>
# <input name="_isDown" type="hidden" value="6155092"/>
# <td class="check"><input buyminquality="T" disc_id="1" name="check" title="사건의 지평선" type="checkbox" value="6155092"/></td>
# <td>
# <div class="ranking">
# <strong>1</strong>
# <p class="change none"><em>0</em><span>변동없음</span></p>
# </div>
# </td>
# <td>
# <a class="thumbnail" href="https://music.bugs.co.kr/album/4073469?wl_ref=list_tr_07_chart" onclick="
# ">
# <span class="mask"></span>
# <img alt="YOUNHA 6th Album Repackage 'END THEORY : Final Edition' 대표이미지" onerror="bugs.utils.imgError(this);" src="https://image.bugsm.co.kr/album/images/50/40734/4073469.jpg?version=20221116004342.0"/>
# </a>
# </td>
# <td>
# <a class="trackInfo" href="https://music.bugs.co.kr/track/6155092?wl_ref=list_tr_08_chart" onclick="
# ">곡정보</a>
# </td>
# <th scope="row">
# ...

# %%
#노래 제목 추출
len(song.select('a'))
# Out:
# 11

# %%
len(song.select('p > a'))
# Out:
# 2

# %%
print(song.select('p > a'))
# Out:
# [<a adultcheckval="1" aria-label="새창" href="javascript:;" onclick="bugs.wiselog.area('list_tr_09_chart');bugs.music.listen('6155092',true);
# " title="사건의 지평선">사건의 지평선</a>, <a href="https://music.bugs.co.kr/artist/80010025?wl_ref=list_tr_10_chart" onclick="
# " title="윤하(Younha/ユンナ)">윤하(Younha/ユンナ)</a>]

# %%
title = song.select('p.title > a')[0].text
print(title)
# Out:
# 사건의 지평선

# %%
len(song.select('a'))
# Out:
# 11

# %%
singer = song.select('p.artist > a')[0].text
print(singer)
# Out:
# 윤하(Younha/ユンナ)

# %%
singer = song.select('p.artist > a')[2].text
print(singer)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-48-aff09c2a19ac> in <module>
# ----> 1 singer = song.select('p.artist > a')[2].text
#       2 print(singer)
#
# IndexError: list index out of range

# %%
title = song.select('table.byChart > tbody > tr')

song = songs[2]
title2 = song.select('p.title > a')[0].text
singer2 = song.select('p.artist > a')[0].text
print(title2)
print(singer2)
# Out:
# Hype Boy
# NewJeans

# %%
song_data = []
rank = 1

#전체 노래 100 곡 다시 추출

url = "https://music.bugs.co.kr/chart"
html = requests.get(url)
soup = bs(html.text)
song.select('table.byChart > tbody > tr')

for i in range(0,100):
    song = songs[i]
    title =  song.select('p.title > a')[0].text
    singer = song.select('p.artist > a')[0].text
    song_data.append(['Bugs', rank , title , singer])
    rank += 1
  
print(song_data)
# Out:
# [['Bugs', 1, '사건의 지평선', '윤하(Younha/ユンナ)'], ['Bugs', 2, 'WHEN I MOVE', '카라(Kara)'], ['Bugs', 3, 'Hype Boy', 'NewJeans'], ['Bugs', 4, 'ANTIFRAGILE', 'LE SSERAFIM (르세라핌)'], ['Bugs', 5, 'After LIKE', 'IVE (아이브)'], ['Bugs', 6, 'Dreamers [Music from the FIFA World Cup Qatar 2022 Official Soundtrack] (feat. FIFA Sound)', '정국'], ['Bugs', 7, 'Attention', 'NewJeans'], ['Bugs', 8, 'Nxde', '(여자)아이들'], ['Bugs', 9, 'LOVE DIVE', 'IVE (아이브)'], ['Bugs', 10, '새삥 (Prod. ZICO) (Feat. 호미들)', '지코'], ['Bugs', 11, 'Snowman', 'Sia(시아)'], ['Bugs', 12, 'Shut Down', 'BLACKPINK'], ['Bugs', 13, 'All I Want for Christmas Is You', 'Mariah Carey(머라이어 캐리)'], ['Bugs', 14, '마이웨이 (MY WAY) (Prod. R.Tee)', '저스디스(JUSTHIS)'], ['Bugs', 15, '오르트구름', '윤하(Younha/ユンナ)'], ['Bugs', 16, 'STEP', '카라(Kara)'], ['Bugs', 17, 'Rush Hour (Feat. j-hope of BTS)', 'Crush'], ['Bugs', 18, 'Santa Tell Me', 'Ariana Grande(아리아나 그란데)'], ['Bugs', 19, 'Pink Venom', 'BLACKPINK'], ['Bugs', 20, 'Birthday', 'Red Velvet (레드벨벳)'], ['Bugs', 21, 'Monologue'
# ...
